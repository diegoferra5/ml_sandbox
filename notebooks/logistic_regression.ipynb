# %% [markdown]
# # Logistic classification

# %% [markdown]
# ## 1. Problem 1
#
# Question: Does a person has a insurance according to their age?

# %%
import pandas as pd

df = pd.read_csv("../data/processed/insurance_data.csv")

df.head(10)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1
# 5   56                 1
# 6   55                 0
# 7   60                 1
# 8   62                 1
# 9   61                 1

# %%
import matplotlib.pyplot as plt 
plt.scatter(df['age'], df['bought_insurance'], marker='+', color='red')
plt.xlabel('age')
plt.ylabel("bought insurance")
# Out:
# Text(0, 0.5, 'bought insurance')

# %%
df.shape
# Out:
# (27, 2)

# %%
df.dtypes
# Out:
# age                 int64
# bought_insurance    int64
# dtype: object

# %% [markdown]
# split data

# %%
from sklearn.model_selection import train_test_split


X= df[['age']]
y= df[['bought_insurance']]

X_train, X_test, y_train, y_test = train_test_split(
    X,y,
    train_size=0.9,
    random_state=42,
    stratify=y
)

# %% [markdown]
# train model

# %%
from sklearn.linear_model import LogisticRegression

reg = LogisticRegression()
reg.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/my-ml-project/lib/python3.11/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# predict

# %%
y_pred= reg.predict(X_test)
y_pred
# Out:
# array([1, 1, 0])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
X_test
# Out:
#     age
# 15   55
# 25   54
# 12   27

# %% [markdown]
# probabilities of being in class o or 1

# %%
reg.predict_proba(X_test)
# Out:
# array([[0.11896851, 0.88103149],
#        [0.13268298, 0.86731702],
#        [0.81637222, 0.18362778]])
